# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn

# %%
data = pd.read_csv(r"abalone.csv")

# %%
data.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings   Age
# 0         0.150     15  16.5
# 1         0.070      7   8.5
# 2         0.210      9  10.5
# 3         0.155     10  11.5
# 4         0.055      7   8.5

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
#  9   Age             4177 non-null   float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 326.5+ KB

# %% [markdown]
# # Univarient analysis

# %%
sns.distplot(data['Age'])
# Out:
# C:\Users\nandhitha\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.boxplot(data['Age'])
# Out:
# C:\Users\nandhitha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# # Bivarient analysis

# %%
sns.scatterplot(data['Age'], data['Length'])
# Out:
# C:\Users\nandhitha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Length'>

# %%
plt.figure(figsize=(10,10))
sns.barplot(data['Age'], data['Rings'])
# Out:
# C:\Users\nandhitha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Rings'>

# %% [markdown]
# # Multivarient Analysis

# %%
data.corr()
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
# Age             0.556720  0.574660  0.557467      0.540390        0.420884
#
#                 Viscera weight  Shell weight     Rings       Age
# Length                0.903018      0.897706  0.556720  0.556720
# Diameter              0.899724      0.905330  0.574660  0.574660
# Height                0.798319      0.817338  0.557467  0.557467
# Whole weight          0.966375      0.955355  0.540390  0.540390
# Shucked weight        0.931961      0.882617  0.420884  0.420884
# Viscera weight        1.000000      0.907656  0.503819  0.503819
# Shell weight          0.907656      1.000000  0.627574  0.627574
# Rings                 0.503819      0.627574  1.000000  1.000000
# Age                   0.503819      0.627574  1.000000  1.000000

# %%
sns.scatterplot(data['Age'], data['Rings'], hue = data['Sex'])
# Out:
# C:\Users\nandhitha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Rings'>

# %%
sns.pairplot(data)

# %%
sns.heatmap(data.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Descriptive Statictics on data

# %%
data.mean()
# Out:
# C:\Users\nandhitha\AppData\Local\Temp\ipykernel_18456\531903386.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean()
# Length             0.523992
# Diameter           0.407881
# Height             0.139516
# Whole weight       0.828742
# Shucked weight     0.359367
# Viscera weight     0.180594
# Shell weight       0.238831
# Rings              9.933684
# Age               11.433684
# dtype: float64

# %%
data.median()
# Out:
# C:\Users\nandhitha\AppData\Local\Temp\ipykernel_18456\4184645713.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.median()
# Length             0.5450
# Diameter           0.4250
# Height             0.1400
# Whole weight       0.7995
# Shucked weight     0.3360
# Viscera weight     0.1710
# Shell weight       0.2340
# Rings              9.0000
# Age               10.5000
# dtype: float64

# %%
data.mode()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    M   0.550      0.45    0.15        0.2225           0.175
# 1  NaN   0.625       NaN     NaN           NaN             NaN
#
#    Viscera weight  Shell weight  Rings   Age
# 0          0.1715         0.275    9.0  10.5
# 1             NaN           NaN    NaN   NaN

# %%
data.std()
# Out:
# C:\Users\nandhitha\AppData\Local\Temp\ipykernel_18456\2723740006.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.std()
# Length            0.120093
# Diameter          0.099240
# Height            0.041827
# Whole weight      0.490389
# Shucked weight    0.221963
# Viscera weight    0.109614
# Shell weight      0.139203
# Rings             3.224169
# Age               3.224169
# dtype: float64

# %%
data.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings          Age
# count     4177.000000   4177.000000  4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684    11.433684
# std          0.109614      0.139203     3.224169     3.224169
# min          0.000500      0.001500     1.000000     2.500000
# 25%          0.093500      0.130000     8.000000     9.500000
# 50%          0.171000      0.234000     9.000000    10.500000
# 75%          0.253000      0.329000    11.000000    12.500000
# max          0.760000      1.005000    29.000000    30.500000

# %%
data['Age'].unique()
# Out:
# array([16.5,  8.5, 10.5, 11.5,  9.5, 21.5, 17.5, 20.5, 15.5, 12.5, 13.5,
#        19.5, 14.5,  6.5,  5.5,  7.5, 22.5, 18.5, 23.5,  2.5,  4.5, 27.5,
#        24.5, 30.5,  3.5, 28.5, 26.5, 25.5])

# %% [markdown]
# # Deal with missing values

# %%
data.isnull().any()
# Out:
# Sex               False
# Length            False
# Diameter          False
# Height            False
# Whole weight      False
# Shucked weight    False
# Viscera weight    False
# Shell weight      False
# Rings             False
# Age               False
# dtype: bool

# %% [markdown]
# # Find and replace outliers

# %%
sns.boxplot(data['Age'])
# Out:
# C:\Users\nandhitha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
q  = data.quantile([0.75,0.25])

# %%
q
# Out:
#       Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0.75   0.615      0.48   0.165        1.1530           0.502          0.2530
# 0.25   0.450      0.35   0.115        0.4415           0.186          0.0935
#
#       Shell weight  Rings   Age
# 0.75         0.329   11.0  12.5
# 0.25         0.130    8.0   9.5

# %%
iqr =  q.iloc[0] - q.iloc[1]

# %%
iqr
# Out:
# Length            0.1650
# Diameter          0.1300
# Height            0.0500
# Whole weight      0.7115
# Shucked weight    0.3160
# Viscera weight    0.1595
# Shell weight      0.1990
# Rings             3.0000
# Age               3.0000
# dtype: float64

# %%
u = q.iloc[0] + (1.5*iqr)

# %%
u
# Out:
# Length             0.86250
# Diameter           0.67500
# Height             0.24000
# Whole weight       2.22025
# Shucked weight     0.97600
# Viscera weight     0.49225
# Shell weight       0.62750
# Rings             15.50000
# Age               17.00000
# dtype: float64

# %%
l = q.iloc[1] - (1.5*iqr)

# %%
l
# Out:
# Length            0.20250
# Diameter          0.15500
# Height            0.04000
# Whole weight     -0.62575
# Shucked weight   -0.28800
# Viscera weight   -0.14575
# Shell weight     -0.16850
# Rings             3.50000
# Age               5.00000
# dtype: float64

# %%
data['Age'] = np.where(data['Age']>17,11, data['Age'])

# %%
sns.boxplot(data['Age'])
# Out:
# C:\Users\nandhitha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# # Categorical column Encoding

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
lblenc = LabelEncoder()
onehenc = OneHotEncoder()
data['Sex'] = lblenc.fit_transform(data['Sex'])

# %%
data.head(15)
# Out:
#     Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0     2   0.455     0.365   0.095        0.5140          0.2245
# 1     2   0.350     0.265   0.090        0.2255          0.0995
# 2     0   0.530     0.420   0.135        0.6770          0.2565
# 3     2   0.440     0.365   0.125        0.5160          0.2155
# 4     1   0.330     0.255   0.080        0.2050          0.0895
# 5     1   0.425     0.300   0.095        0.3515          0.1410
# 6     0   0.530     0.415   0.150        0.7775          0.2370
# 7     0   0.545     0.425   0.125        0.7680          0.2940
# 8     2   0.475     0.370   0.125        0.5095          0.2165
# 9     0   0.550     0.440   0.150        0.8945          0.3145
# 10    0   0.525     0.380   0.140        0.6065          0.1940
# 11    2   0.430     0.350   0.110        0.4060          0.1675
# 12    2   0.490     0.380   0.135        0.5415          0.2175
# 13    0   0.535     0.405   0.145        0.6845          0.2725
# 14    0   0.470     0.355   0.100        0.4755          0.1675
#
#     Viscera weight  Shell weight  Rings   Age
# 0           0.1010         0.150     15  16.5
# 1           0.0485         0.070      7   8.5
# 2           0.1415         0.210      9  10.5
# 3           0.1140         0.155     10  11.5
# 4           0.0395         0.055      7   8.5
# 5           0.0775         0.120      8   9.5
# 6           0.1415         0.330     20  11.0
# 7           0.1495         0.260     16  11.0
# 8           0.1125         0.165      9  10.5
# 9           0.1510         0.320     19  11.0
# 10          0.1475         0.210     14  15.5
# 11          0.0810         0.135     10  11.5
# 12          0.0950         0.190     11  12.5
# 13          0.1710         0.205     10  11.5
# 14          0.0805         0.185     10  11.5

# %% [markdown]
# # 8. Split the data into dependent and independent variables.

# %%
x = data.iloc[:, 0:9]

# %%
x
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
y = data['Age']

# %%
y
# Out:
# 0       16.5
# 1        8.5
# 2       10.5
# 3       11.5
# 4        8.5
#         ...
# 4172    12.5
# 4173    11.5
# 4174    10.5
# 4175    11.5
# 4176    13.5
# Name: Age, Length: 4177, dtype: float64

# %% [markdown]
# # Scalling the independent variables

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
sc = StandardScaler()
x_scale = sc.fit_transform(x)

# %%
x_scale
# Out:
# array([[ 1.15198011, -0.57455813, -0.43214879, ..., -0.72621157,
#         -0.63821689,  1.57154357],
#        [ 1.15198011, -1.44898585, -1.439929  , ..., -1.20522124,
#         -1.21298732, -0.91001299],
#        [-1.28068972,  0.05003309,  0.12213032, ..., -0.35668983,
#         -0.20713907, -0.28962385],
#        ...,
#        [ 1.15198011,  0.6329849 ,  0.67640943, ...,  0.97541324,
#          0.49695471, -0.28962385],
#        [-1.28068972,  0.84118198,  0.77718745, ...,  0.73362741,
#          0.41073914,  0.02057072],
#        [ 1.15198011,  1.54905203,  1.48263359, ...,  1.78744868,
#          1.84048058,  0.64095986]])

# %% [markdown]
# # Splitting the data into train and test

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_scale, y, test_size = 0.3, random_state = 0)

# %%
x_train
# Out:
# array([[ 1.15198011,  0.79954256,  1.0291325 , ...,  0.52833755,
#          1.0860944 ,  0.02057072],
#        [-0.0643548 , -1.49062526, -1.54070702, ..., -1.31014717,
#         -1.35667992, -1.53040213],
#        [-0.0643548 , -1.24078877, -1.33915098, ..., -1.15047728,
#         -1.24172584, -0.91001299],
#        ...,
#        [ 1.15198011,  0.59134549,  0.42446438, ...,  0.23636976,
#          0.10539235,  0.02057072],
#        [-1.28068972,  0.84118198,  0.82757646, ...,  0.51008957,
#          0.57239333, -0.28962385],
#        [-0.0643548 , -0.94931287, -0.83526087, ..., -0.96343541,
#         -0.99026378, -0.59981842]])

# %%
x_test
# Out:
# array([[ 1.15198011,  0.21659075,  0.17251933, ...,  0.56939553,
#          0.69093973,  0.95115443],
#        [-0.0643548 , -0.1998034 , -0.07942572, ..., -0.34300384,
#         -0.32568547, -0.59981842],
#        [ 1.15198011,  0.79954256,  0.72679844, ...,  1.7646387 ,
#          0.56520869,  0.33076529],
#        ...,
#        [-1.28068972,  0.92446081,  0.87796547, ...,  1.16245511,
#          0.35685441, -0.28962385],
#        [ 1.15198011,  1.13265788,  0.97874349, ...,  1.06209118,
#          2.66671307,  2.50212727],
#        [-0.0643548 ,  0.79954256,  0.77718745, ...,  1.13052114,
#          0.65501657,  1.57154357]])

# %%
y_train
# Out:
# 1376    11.5
# 1225     6.5
# 2722     8.5
# 3387    11.0
# 2773    12.5
#         ...
# 1033    11.5
# 3264    13.5
# 1653    11.5
# 2607    10.5
# 2732     9.5
# Name: Age, Length: 2923, dtype: float64

# %%
y_test
# Out:
# 668     14.5
# 1580     9.5
# 3784    12.5
# 463      6.5
# 2615    13.5
#         ...
# 1052    13.5
# 3439     9.5
# 1174    10.5
# 2210    11.0
# 2408    16.5
# Name: Age, Length: 1254, dtype: float64

# %% [markdown]
# # Model Building Simple Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred = lr.predict(x_test)

# %%
pred
# Out:
# array([12.28352606, 10.10575924, 12.29282896, ..., 11.07618855,
#        13.8684903 , 13.77023834])

# %%
y_test
# Out:
# 668     14.5
# 1580     9.5
# 3784    12.5
# 463      6.5
# 2615    13.5
#         ...
# 1052    13.5
# 3439     9.5
# 1174    10.5
# 2210    11.0
# 2408    16.5
# Name: Age, Length: 1254, dtype: float64

# %% [markdown]
# # Measuring the performance using metrics

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(pred,y_test)

# %%
mse
# Out:
# 2.04681979763011

# %%
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# 1.4306711004385704

# %%
r2_score(pred, y_test)
# Out:
# 0.40727284218957405

# %% [markdown]
# # Random Forest Regerssor

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=100)
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
model.score(x_test,y_test)
# Out:
# 0.9999000045979065

# %%
pred_test = model.predict(x_test)

# %%
pred_test
# Out:
# array([14.5,  9.5, 12.5, ..., 10.5, 11. , 16.5])

# %%
y_test
# Out:
# 668     14.5
# 1580     9.5
# 3784    12.5
# 463      6.5
# 2615    13.5
#         ...
# 1052    13.5
# 3439     9.5
# 1174    10.5
# 2210    11.0
# 2408    16.5
# Name: Age, Length: 1254, dtype: float64

# %% [markdown]
# # Measuring the performance using metrics

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(pred_test,y_test)

# %%
mse
# Out:
# 0.0005767145135566182

# %%
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# 0.0240148810856231

# %%
r2_score(pred_test, y_test)
# Out:
# 0.9998998285167056
